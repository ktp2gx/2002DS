# %% [markdown]
# <a href="https://colab.research.google.com/github/ktp2gx/2002DS/blob/main/Basketball_Hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

acc_players_df = pd.read_csv('/content/acc_players-2324F.csv')

acc_players_df.head()
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4 Totals  \
# 0         Rk         Player      Class        Pos          School      G
# 1          1   Amaree Abram         SO          G    Georgia Tech     10
# 2          2   Sola Adebisi         FR          F   Florida State      7
# 3          3  Prince Aligbe         SO          F  Boston College     35
# 4          4     Abe Atiyeh         SR          G  Boston College      4
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0         MP        TRB        AST        STL  ...         TOV          PF
# 1        108         17         11          1  ...           9          10
# 2          9          1          1          0  ...           1           1
# 3        651        119         21         15  ...          30          51
# 4          6          0          0          0  ...           1           0
#
#   Unnamed: 13 Shooting Unnamed: 15 Unnamed: 16 Unnamed: 17 Advanced  \
# ...

# %%
acc_players_df.columns = acc_players_df.iloc[0]
acc_players_df = acc_players_df.drop(0).reset_index(drop=True)
acc_players_df.head()
# Out:
# 0 Rk         Player Class Pos          School   G   MP  TRB AST STL  ... TOV  \
# 0  1   Amaree Abram    SO   G    Georgia Tech  10  108   17  11   1  ...   9
# 1  2   Sola Adebisi    FR   F   Florida State   7    9    1   1   0  ...   1
# 2  3  Prince Aligbe    SO   F  Boston College  35  651  119  21  15  ...  30
# 3  4     Abe Atiyeh    SR   G  Boston College   4    6    0   0   0  ...   1
# 4  5    Zack Austin    JR   F      Pittsburgh  33  746  137  29  32  ...  13
#
# 0  PF  PTS    FG%    2P%    3P%    FT%  PER    WS   BPM
# 0  10   34  0.262  0.318    0.2  0.615  4.1  -0.1  -6.4
# 1   1    2    0.5    0.5    NaN    NaN  3.5     0  -6.7
# 2  51  164  0.435  0.522  0.147   0.62  9.4   0.9  -1.3
# 3   0    3  0.333      0      1    NaN  1.1     0  -8.2
# 4  35  216  0.417  0.563  0.295  0.737   18   2.9   7.9
#
# [5 rows x 21 columns]

# %%
#2 Calculate the total points scored by all players combined

acc_total_PTS = acc_players_df['PTS'].sum()
print(acc_total_PTS)
# Out:
# 38411

# %%
#2 Find the player who has played the most minutes (MP)
most_minutes_player = acc_players_df.loc[acc_players_df['MP'].idxmax()]['Player']
print(most_minutes_player)
# Out:
# Ian Schieffelin

# %%
#2 Identify the top 5 players in terms of total rebounds (TRB)
acc_players_df['TRB'] = pd.to_numeric(acc_players_df['TRB'])

top_5_rebounds = acc_players_df.nlargest(5, 'TRB')['Player']
print(top_5_rebounds)
# Out:
# 5        Armando Bacot
# 178    Ian Schieffelin
# 90     Harrison Ingram
# 44      Mohamed Diarra
# 149      Norchad Omier
# Name: Player, dtype: object

# %%
#3 Create a new DataFrame containing only players who played more than 500 minutes.
acc_players_df['MP'] = pd.to_numeric(acc_players_df['MP'])
playing_players_df = acc_players_df[acc_players_df['MP'] > 500]
print(playing_players_df)
# Out:
# 0     Rk            Player Class Pos          School   G    MP  TRB  AST STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21  15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29  32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56  22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212  68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21  18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ..
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91  64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39  24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33   6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20  12
# 215  216    Jaeden Zackery    JR   G  Boston College  36  1216  119  152  63
#
# ...

# %%
#3 player with the highest total assists (AST).
highest_assists = playing_players_df.loc[playing_players_df['AST'].idxmax()]['Player']
print(highest_assists)
# Out:
# Jalen Warley

# %%
#3 Top 3 Assist Leads in the League
playing_players_df['AST'] = pd.to_numeric(playing_players_df['AST'])
top_3_assists = playing_players_df.sort_values(by='AST', ascending=False).head(3)['Player']
print(top_3_assists)
# Out:
# 135    Casey Morsell
# 81          DJ Horne
# 42          RJ Davis
# Name: Player, dtype: object
# <ipython-input-34-2b474c032b9f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_players_df['AST'] = pd.to_numeric(playing_players_df['AST'])

# %%
#3 Top 3 Shot Blockers
playing_players_df['STL'] = pd.to_numeric(playing_players_df['STL'])
top_3_shot_blockers = playing_players_df.sort_values(by='STL', ascending=False).head(3)['Player']
print(top_3_shot_blockers)
# Out:
# 16       Maliq Brown
# 7      Reece Beekman
# 132      Judah Mintz
# Name: Player, dtype: object
# <ipython-input-35-220c2e1de3f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playing_players_df['STL'] = pd.to_numeric(playing_players_df['STL'])

# %%
#4 Group the players by School and calculate the total points scored by each school.
acc_players_df['PTS'] = pd.to_numeric(acc_players_df['PTS'])
school_points = acc_players_df.groupby('School')['PTS'].sum()
print(school_points)
# Out:
# School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64

# %%
#4 Group the players by School and calculate the total assists (AST) for each team
school_assists = acc_players_df.groupby('School')['AST'].sum()
print(school_assists)
# Out:
# School
# Boston College       2100117204350459310003152
# Clemson              2635105285171164600608033
# Duke                  013100582683651180114730
# Florida State     1801673321263300467015109291
# Georgia Tech          112218224135593280284091
# Louisville               870733471095031413920
# Miami (FL)               804876711003388961518
# NC State          1172484025670130111010055102
# North Carolina        561501291380000443272113
# Notre Dame          15214303310340182020029317
# Pittsburgh              2913636123326076110930
# Syracuse                2159108915111420603122
# Virginia               21215122662133154929901
# Virginia Tech        3826487361844148243300218
# Wake Forest            15110218441321247440860
# Name: AST, dtype: object

# %%
#4 Sort the schools by total points scored and display the top 3 schools
top_3_schools = school_points.nlargest(3)
print(top_3_schools)
# Out:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# Name: PTS, dtype: int64
